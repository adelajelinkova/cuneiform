# %%
#import all libraries if GPU is found
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
else:
  gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.7)
  print('Found GPU at: {}'.format(device_name))
  import os                          
  import cv2                          
  import keras      
  import fnmatch                  
  import pandas as pd                
  import matplotlib.pyplot as plt     
  import numpy as np
  import re
  from keras.layers import Dense                                  
  from keras.layers import Input 
  from keras.layers import Conv2D
  from keras.layers import MaxPool2D
  from keras.layers import Flatten                                
  from keras import Model                                         
  from keras.models import Sequential                                   
  from keras import optimizers   
  from keras.preprocessing.image import ImageDataGenerator        
  from keras.preprocessing import image                           
  from tensorflow.keras.optimizers import Adam                    
  from tensorflow.keras.optimizers import RMSprop                 
  from keras.applications.vgg16 import VGG16                   
  from sklearn.model_selection import train_test_split 
  from sklearn.preprocessing import LabelBinarizer
  from keras.callbacks import ModelCheckpoint, EarlyStopping
  from roboflow import Roboflow
  from npy_append_array import NpyAppendArray
# Out:
# Found GPU at: /device:GPU:0

# %%
device_name = "culs"

# %%
dataset_name         = "224_full"    #"224_half", "224_full" "416_full", "416_half"
if (device_name == "culs"):
    project_dir = "C:/Users/cejkamartin/OneDrive - CZU v Praze/Dokumenty/rcnn_cuneiform/"
if (device_name == "MSI"):
    project_dir = "C:/Users/infin/AppData/Local/Packages/KaliLinux.54290C8133FEE_ey8k8hqnwqnmg/LocalState/rootfs/home/kali/rcnn_cuneiform"
if (device_name == ''):
    project_dir = os.cwd()

temp_dir        = os.path.join(project_dir, 'data')
data_dir        = os.path.join(project_dir, 'data', dataset_name)
train_set_dir   = os.path.join(project_dir, 'train_sets')
models_dir      = os.path.join(project_dir, 'models')
results_dir     = os.path.join(project_dir, 'results')
test_data_dir   = os.path.join(project_dir, 'data', 'test')
log_dir         = os.path.join(project_dir, 'logs')


data_exist          = os.path.exists(temp_dir)
data_dir_exist      = os.path.exists(data_dir)
train_set_dir_exist = os.path.exists(data_dir)
models_dir_exist    = os.path.exists(models_dir)
results_dir_exist   = os.path.exists(results_dir)
test_data_dir_exist = os.path.exists(test_data_dir)
log_dir_exist       = os.path.exists(log_dir)


if(data_exist == False):
    os.chdir(project_dir)
    os.makedirs('data')

if(data_dir_exist == False):
    os.chdir(data_dir)
    os.makedirs(dataset_name)

if(train_set_dir_exist == False):
    os.chdir(project_dir)
    os.makedirs('train_sets')

if(models_dir_exist == False):
    os.chdir(project_dir)
    os.makedirs('models')

if(results_dir_exist == False):
    os.chdir(project_dir)
    os.makedirs('results')

if(test_data_dir_exist == False):
    os.chdir(temp_dir)
    os.makedirs('test')

if(log_dir_exist == False):
    os.chdir(project_dir)
    os.makedirs('logs')

# %%
os.chdir(data_dir)
rf_version = 14
rf = Roboflow(api_key="F5c4lxwDSV274e9l8AhW")
project = rf.workspace().project("hstrokes_avital")
dataset = project.version(rf_version).download("yolov5")

# %%
images  =   os.path.join(data_dir, "images")
annot   =   os.path.join(data_dir, "labels")

cv2.setUseOptimized(True);
early_stop = True;
train_data_set_exists = True;

error_function          = keras.losses.binary_crossentropy
optimizer               = Adam
model_architecture      = "vgg_imagenet"    #"vgg_imagenet" "vgg_none" "own_4cl" "vgg_imagenet_tl"
do_augmentation         = False

max_samples             = 55                #maximum positive and negative samples in one image
ss_iterate_results      = 2000 
iou_object_limit        = 0.7
iou_background_limit    = 0.3
image_edge_lenght       = 224
depth                   = 1                 #image depths (1=black&white, 3=RGB)
split_ratio             = 0.1               #train & test split ration

number_of_classes       = 2
learning_rate           = 0.0001

patience_epochs         = 20          #before early stopping stops
training_epochs         = 100    
steps_in_epoch          = 10
save_frequency          = 1
validation_steps        = 5

#define variables for training set ant testing set and its labels as arrays
train_images=[]
train_labels=[]

X_new = np.array(train_images)
y_new = np.array(train_labels)

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']
    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])
    if x_right < x_left or y_bottom < y_top:
        return 0.0
    intersection_area = (x_right - x_left) * (y_bottom - y_top)
    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])
    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
train_set_name = 'SS_' + str(dataset_name) + '-' + str(ss_iterate_results) + '-' + str(max_samples) + '-' + str(iou_object_limit) + '-' + str(iou_background_limit)
os.chdir(data_dir)
for e,i in enumerate(os.listdir(annot)):
    try:
        if i.startswith("proc"):
            filename = i.replace(".txt", ".jpg")
            print(e,filename)
            image = cv2.imread(os.path.join(images,filename))
            plt.imshow(image)
            df = pd.read_csv(os.path.join(annot,i), header=None, error_bad_lines=False)
            gtvalues=[]
            for row in df.iterrows():
                pivot_x = float(row[1][0].split(" ")[1])*image_edge_lenght
                pivot_y = float(row[1][0].split(" ")[2])*image_edge_lenght
                width   = float(row[1][0].split(" ")[3])*image_edge_lenght
                height  = float(row[1][0].split(" ")[4])*image_edge_lenght
                x1 = int(round(pivot_x - (width  / 2)))
                x2 = int(round(pivot_x + (width  / 2)))
                y1 = int(round(pivot_y - (height / 2)))
                y2 = int(round(pivot_y + (height / 2)))
                gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
            print(gtvalues)
            ss.setBaseImage(image)
            ss.switchToSelectiveSearchFast()
            ssresults = ss.process()
            imout = image.copy()
            counter = 0
            falsecounter = 0
            flag = 0
            fflag = 0
            bflag = 0
            for e,result in enumerate(ssresults):
                if e < ss_iterate_results and flag == 0:
                    for gtval in gtvalues:
                        x,y,w,h = result
                        iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                        if counter < max_samples:
                            if iou > iou_object_limit:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (image_edge_lenght,image_edge_lenght), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(1)
                                counter += 1
                        else :
                            fflag =1
                        if falsecounter < max_samples:
                            if iou < iou_background_limit:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (image_edge_lenght,image_edge_lenght), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(0)
                                falsecounter += 1
                        else :
                            bflag = 1
                    if fflag == 1 and bflag == 1:
                        print("inside")
                        flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)
        continue

# %%
os.chdir(train_set_dir)
train_set_name = 'SS_' + str(dataset_name) + '-' + str(ss_iterate_results) + '-' + str(max_samples) + '-' + str(iou_object_limit) + '-' + str(iou_background_limit)
if(train_data_set_exists==True):
    X_new = np.load(train_set_name + '_images.npy', mmap_mode="r")
    y_new = np.load(train_set_name + '_labels.npy', mmap_mode="r")
if(train_data_set_exists==False):
    with NpyAppendArray(train_set_name + '_images.npy') as npaa:
        npaa.append(np.array(train_images))
    with NpyAppendArray(train_set_name + '_labels.npy') as npaa:
        npaa.append(np.array(train_labels))
    X_new = np.array(train_images)
    y_new = np.array(train_labels)

print(X_new.size, y_new.size)
# Out:
# 21088822272 140099

# %%
train_images.clear()
train_labels.clear()
del data_exist, data_dir_exist, train_set_dir_exist, models_dir_exist, results_dir_exist, test_data_dir_exist

# %%
opt = optimizer (learning_rate=learning_rate)

if (model_architecture == "vgg_imagenet"):
    vggmodel = VGG16(weights='imagenet', include_top=True)
    X = vggmodel.layers[-2].output
    predictions = Dense(number_of_classes, activation="softmax")(X)
    model_final = Model(vggmodel.input, predictions)
    model_final.summary()
    model_final.compile(loss = error_function, optimizer = opt, metrics=["accuracy"])
if (model_architecture == "vgg_none"):
    vggmodel = VGG16(weights=None, include_top=True)
    X = vggmodel.layers[-2].output
    predictions = Dense(number_of_classes, activation="softmax")(X)
    model_final = Model(vggmodel.input, predictions)
    model_final.summary()
    model_final.compile(loss = error_function, optimizer = opt, metrics=["accuracy"])
if (model_architecture == "own_4cl"):
    model = Sequential()
    model.add(Conv2D(nodes_first_layer,
                    kernel_size=filter_matrix,
                    activation='relu',
                    input_shape=(image_edge_lenght,image_edge_lenght,3)))
    model.add(MaxPool2D((2,2)))
    model.add(Conv2D(nodes_second_layer,
                    kernel_size=filter_matrix, 
                    activation='relu'))
    model.add(MaxPool2D((2,2)))
    model.add(Conv2D(nodes_third_layer, (3,3)))
    model.add(MaxPool2D((2,2)))
    model.add(Conv2D(nodes_fourth_layer,(3,3)))
    model.add(MaxPool2D((2,2)))
    model.add(Flatten())
    model.add(Dense(number_of_classes, activation='softmax'))
    model_final = model
    model_final.compile(loss = error_function, optimizer = opt, metrics=["accuracy"])
    model_final.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense (Dense)               (None, 2)                 8194
#
# =================================================================
# Total params: 134,268,738
# Trainable params: 134,268,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Hot encode one label -> split the dataset into train and test set
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)
X_train, X_test , y_train, y_test = train_test_split(X_new,Y,test_size=split_ratio, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11012\2105744464.py in <module>
#       1 #Hot encode one label -> split the dataset into train and test set
# ----> 2 class MyLabelBinarizer(LabelBinarizer):
#       3     def transform(self, y):
#       4         Y = super().transform(y)
#       5         if self.y_type_ == 'binary':
#
# NameError: name 'LabelBinarizer' is not defined

# %%
del X_new
del Y

# %%
if (do_augmentation == False):
    trdata = ImageDataGenerator()
    tsdata = ImageDataGenerator()
if (do_augmentation == True):
    trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
    tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)

traindata = trdata.flow(x=X_train, y=y_train)
testdata = tsdata.flow(x=X_test, y=y_test)

# %%
os.chdir(project_dir)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir="./logs")
if (early_stop == True):
    checkpoint = ModelCheckpoint("rcnn_vgg16_1.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq=save_frequency)
    early = EarlyStopping(monitor='val_loss', min_delta=0, patience=patience_epochs, verbose=1, mode='auto')
    hist = model_final.fit_generator(generator= traindata, steps_per_epoch= steps_in_epoch, epochs= training_epochs, validation_data= testdata, validation_steps= validation_steps, callbacks=[checkpoint,early,tensorboard_callback])
if (early_stop == False):
    hist = model_final.fit_generator(generator= traindata, steps_per_epoch= steps_in_epoch, epochs= training_epochs, validation_data= testdata, validation_steps= validation_steps)
# Out:
# C:\Users\cejkamartin\AppData\Local\Temp\ipykernel_10780\2164115887.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model_final.fit_generator(generator= traindata, steps_per_epoch= steps_in_epoch, epochs= training_epochs, validation_data= testdata, validation_steps= validation_steps, callbacks=[checkpoint,early,tensorboard_callback])
# Epoch 1/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 3:05 - loss: 0.3556 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.4763 - accuracy: 0.9531  WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.5176 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.3933 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.3146 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.4650 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.3986 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.3489 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3102 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 26s 646ms/step - loss: 0.3159 - accuracy: 0.9781 - val_loss: 0.1474 - val_accuracy: 0.9688
# Epoch 2/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.1407 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1683 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1582 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1975 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.2547 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.2578 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.2386 - accuracy: 0.9643WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.2392 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2285 - accuracy: 0.9618WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 551ms/step - loss: 0.2105 - accuracy: 0.9656 - val_loss: 0.0921 - val_accuracy: 0.9812
# Epoch 3/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.1483 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1413 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.1389 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1136 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0961 - accuracy: 0.9812WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1299 - accuracy: 0.9740WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1141 - accuracy: 0.9777WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1452 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1374 - accuracy: 0.9722WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 567ms/step - loss: 0.1460 - accuracy: 0.9688 - val_loss: 0.1300 - val_accuracy: 0.9750
# Epoch 4/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.1405 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0895 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.0660 - accuracy: 0.9896WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1267 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1639 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1984 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.2008 - accuracy: 0.9598WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1928 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1750 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 554ms/step - loss: 0.1712 - accuracy: 0.9656 - val_loss: 0.1908 - val_accuracy: 0.9625
# Epoch 5/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0066 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1721 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.1603 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1319 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1823 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1617 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1465 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1313 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1176 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 549ms/step - loss: 0.1490 - accuracy: 0.9750 - val_loss: 0.2038 - val_accuracy: 0.9625
# Epoch 6/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.3413 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.2372 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.2042 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1896 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1838 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.2016 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1910 - accuracy: 0.9643WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1892 - accuracy: 0.9648WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1739 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 550ms/step - loss: 0.1585 - accuracy: 0.9719 - val_loss: 0.2284 - val_accuracy: 0.9563
# Epoch 7/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.2716 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.2318 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.2186 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.2058 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1986 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1680 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1472 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.2003 - accuracy: 0.9570WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1826 - accuracy: 0.9618WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 5s 547ms/step - loss: 0.1678 - accuracy: 0.9656 - val_loss: 0.1647 - val_accuracy: 0.9688
# Epoch 8/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 4s - loss: 0.0105 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.3897 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.2617 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1988 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1913 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1648 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1453 - accuracy: 0.9821WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1282 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1607 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 5s 548ms/step - loss: 0.1456 - accuracy: 0.9812 - val_loss: 0.1427 - val_accuracy: 0.9688
# Epoch 9/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 4s - loss: 0.1416 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1423 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.1425 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1170 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1207 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1501 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1316 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1186 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1077 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 553ms/step - loss: 0.1122 - accuracy: 0.9781 - val_loss: 0.1118 - val_accuracy: 0.9750
# Epoch 10/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.1560 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0892 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1051 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0849 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0720 - accuracy: 0.9875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1257 - accuracy: 0.9740WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1108 - accuracy: 0.9777WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1138 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1168 - accuracy: 0.9757WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 560ms/step - loss: 0.1083 - accuracy: 0.9781 - val_loss: 0.1315 - val_accuracy: 0.9688
# Epoch 11/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.2661 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.2471 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.2664 - accuracy: 0.9271WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.2220 - accuracy: 0.9453WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.2042 - accuracy: 0.9500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1906 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1654 - accuracy: 0.9598WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1672 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1491 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 551ms/step - loss: 0.1507 - accuracy: 0.9656 - val_loss: 0.2363 - val_accuracy: 0.9625
# Epoch 12/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.3526 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1848 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.1710 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1457 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1467 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1331 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1480 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1458 - accuracy: 0.9727WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1555 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 554ms/step - loss: 0.1612 - accuracy: 0.9656 - val_loss: 0.2067 - val_accuracy: 0.9500
# Epoch 13/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0451 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1586 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.1337 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1391 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1702 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1443 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1255 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1476 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1328 - accuracy: 0.9722WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 551ms/step - loss: 0.1336 - accuracy: 0.9719 - val_loss: 0.1515 - val_accuracy: 0.9625
# Epoch 14/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0269 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0298 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.0645 - accuracy: 0.9896WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0805 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0882 - accuracy: 0.9812WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.0953 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1165 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1093 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1222 - accuracy: 0.9722WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 560ms/step - loss: 0.1337 - accuracy: 0.9688 - val_loss: 0.1603 - val_accuracy: 0.9563
# Epoch 15/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0546 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0472 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.1056 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0831 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0943 - accuracy: 0.9812WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.0807 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.0927 - accuracy: 0.9821WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1016 - accuracy: 0.9805WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0923 - accuracy: 0.9826WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 559ms/step - loss: 0.1052 - accuracy: 0.9781 - val_loss: 0.2346 - val_accuracy: 0.9375
# Epoch 16/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.2199 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1625 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.1732 - accuracy: 0.9479WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1660 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1510 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1474 - accuracy: 0.9635WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1840 - accuracy: 0.9509WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1743 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1603 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 555ms/step - loss: 0.1663 - accuracy: 0.9563 - val_loss: 0.1756 - val_accuracy: 0.9563
# Epoch 17/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0900 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0581 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.0448 - accuracy: 0.9896WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0656 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0995 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1105 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1266 - accuracy: 0.9643WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1166 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1193 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 562ms/step - loss: 0.1249 - accuracy: 0.9688 - val_loss: 0.1806 - val_accuracy: 0.9500
# Epoch 18/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0173 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0302 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.0551 - accuracy: 0.9896WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0683 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0584 - accuracy: 0.9875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.0722 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.0837 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.0855 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0846 - accuracy: 0.9722WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0818 - accuracy: 0.9750 - val_loss: 0.1894 - val_accuracy: 0.9500
# Epoch 19/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0654 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1189 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1622 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1643 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1333 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1197 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1359 - accuracy: 0.9643WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1221 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1117 - accuracy: 0.9722WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 577ms/step - loss: 0.1018 - accuracy: 0.9750 - val_loss: 0.0605 - val_accuracy: 0.9875
# Epoch 20/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0972 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1426 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1715 - accuracy: 0.9479WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.2518 - accuracy: 0.9219WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.2271 - accuracy: 0.9250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.2159 - accuracy: 0.9323WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.2365 - accuracy: 0.9286WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.2293 - accuracy: 0.9297WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2266 - accuracy: 0.9306WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 582ms/step - loss: 0.2149 - accuracy: 0.9344 - val_loss: 0.0616 - val_accuracy: 0.9875
# Epoch 21/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0195 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0633 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.0849 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0672 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0671 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.0584 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.0870 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1033 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1059 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 581ms/step - loss: 0.1092 - accuracy: 0.9656 - val_loss: 0.0888 - val_accuracy: 0.9625
# Epoch 22/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0751 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0582 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.0492 - accuracy: 0.9896WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0407 - accuracy: 0.9922WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0438 - accuracy: 0.9875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.0370 - accuracy: 0.9896WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.0644 - accuracy: 0.9821WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.0566 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0510 - accuracy: 0.9861WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 583ms/step - loss: 0.0794 - accuracy: 0.9812 - val_loss: 0.0702 - val_accuracy: 0.9875
# Epoch 23/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0427 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0251 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.0569 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0833 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0708 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.0687 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.0767 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.0675 - accuracy: 0.9727WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0701 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0664 - accuracy: 0.9719 - val_loss: 0.0837 - val_accuracy: 0.9750
# Epoch 24/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.2821 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.2249 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1960 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1603 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1474 - accuracy: 0.9563WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.2049 - accuracy: 0.9479WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.2107 - accuracy: 0.9464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1903 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1852 - accuracy: 0.9514WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 581ms/step - loss: 0.1767 - accuracy: 0.9500 - val_loss: 0.1202 - val_accuracy: 0.9625
# Epoch 25/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.1206 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0999 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1556 - accuracy: 0.9479WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1511 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1571 - accuracy: 0.9500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1365 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1380 - accuracy: 0.9598WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1326 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1206 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 573ms/step - loss: 0.1104 - accuracy: 0.9688 - val_loss: 0.1006 - val_accuracy: 0.9625
# Epoch 26/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0137 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.0422 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.0858 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0686 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0603 - accuracy: 0.9812WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1074 - accuracy: 0.9740WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1013 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1233 - accuracy: 0.9648WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1134 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 562ms/step - loss: 0.1172 - accuracy: 0.9656 - val_loss: 0.1105 - val_accuracy: 0.9563
# Epoch 27/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.2046 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.2466 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1844 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1450 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1439 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1358 - accuracy: 0.9740WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1207 - accuracy: 0.9777WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1131 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1194 - accuracy: 0.9722WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 560ms/step - loss: 0.1172 - accuracy: 0.9719 - val_loss: 0.1075 - val_accuracy: 0.9750
# Epoch 28/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.4781 - accuracy: 0.9062WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.2714 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.2517 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.2176 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.2033 - accuracy: 0.9500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.2076 - accuracy: 0.9427WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1976 - accuracy: 0.9420WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1895 - accuracy: 0.9453WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1792 - accuracy: 0.9479WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 548ms/step - loss: 0.1859 - accuracy: 0.9438 - val_loss: 0.1091 - val_accuracy: 0.9625
# Epoch 29/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0343 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1462 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1214 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1222 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# ...
#  6/10 [=================>............] - ETA: 1s - loss: 0.0916 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1010 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.0897 - accuracy: 0.9727WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1134 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 576ms/step - loss: 0.1074 - accuracy: 0.9688 - val_loss: 0.1151 - val_accuracy: 0.9750
# Epoch 31/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 0.0613 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1272 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1023 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0899 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.0861 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.0728 - accuracy: 0.9792WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.0629 - accuracy: 0.9821WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.0551 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0490 - accuracy: 0.9861WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 578ms/step - loss: 0.0441 - accuracy: 0.9875 - val_loss: 1.3948 - val_accuracy: 0.9625
# Epoch 32/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 3.3097e-08 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 1.3623 - accuracy: 0.9688    WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 1.0023 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.8067 - accuracy: 0.9609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.6660 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.5886 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.5113 - accuracy: 0.9598WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.4502 - accuracy: 0.9648WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4007 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 6s 572ms/step - loss: 0.3606 - accuracy: 0.9719 - val_loss: 0.4291 - val_accuracy: 0.9563
# Epoch 33/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 5s - loss: 1.1736e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1677 - accuracy: 0.9844    WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.3049 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.2958 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.2883 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.2834 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.2461 - accuracy: 0.9643WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.2161 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2248 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 5s 524ms/step - loss: 0.2228 - accuracy: 0.9688 - val_loss: 0.3369 - val_accuracy: 0.9688
# Epoch 34/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 4s - loss: 0.3231 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.4077 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.3590 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.3095 - accuracy: 0.9453WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.2971 - accuracy: 0.9438WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.2521 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.2601 - accuracy: 0.9509WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.2595 - accuracy: 0.9492WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2482 - accuracy: 0.9549WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 5s 515ms/step - loss: 0.2301 - accuracy: 0.9594 - val_loss: 0.1752 - val_accuracy: 0.9625
# Epoch 35/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 4s - loss: 0.0204 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1012 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.0691 - accuracy: 0.9896WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.0958 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1118 - accuracy: 0.9812WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1788 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1547 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1369 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1385 - accuracy: 0.9757WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 5s 517ms/step - loss: 0.1613 - accuracy: 0.9688 - val_loss: 0.1677 - val_accuracy: 0.9625
# Epoch 36/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 4s - loss: 0.1501 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1157 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1850 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1517 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1492 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1285 - accuracy: 0.9740WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1305 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1157 - accuracy: 0.9766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1704 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 5s 516ms/step - loss: 0.1683 - accuracy: 0.9656 - val_loss: 0.0924 - val_accuracy: 0.9812
# Epoch 37/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 4s - loss: 0.1420 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1910 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 2s - loss: 0.1763 - accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1496 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1651 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1600 - accuracy: 0.9635WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1428 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1585 - accuracy: 0.9648WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1574 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 5s 515ms/step - loss: 0.1675 - accuracy: 0.9625 - val_loss: 0.1630 - val_accuracy: 0.9625
# Epoch 38/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 4s - loss: 0.2500 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1426 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.1412 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1401 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1418 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1420 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1270 - accuracy: 0.9732WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1286 - accuracy: 0.9727WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1565 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 5s 517ms/step - loss: 0.1547 - accuracy: 0.9656 - val_loss: 0.2013 - val_accuracy: 0.9500
# Epoch 39/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/10 [==>...........................] - ETA: 4s - loss: 0.0467 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/10 [=====>........................] - ETA: 3s - loss: 0.1883 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/10 [========>.....................] - ETA: 3s - loss: 0.2031 - accuracy: 0.9479WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/10 [===========>..................] - ETA: 2s - loss: 0.1877 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/10 [==============>...............] - ETA: 2s - loss: 0.1787 - accuracy: 0.9563WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/10 [=================>............] - ETA: 1s - loss: 0.1569 - accuracy: 0.9635WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/10 [====================>.........] - ETA: 1s - loss: 0.1547 - accuracy: 0.9643WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/10 [=======================>......] - ETA: 0s - loss: 0.1519 - accuracy: 0.9648WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1383 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/10 [==============================] - 5s 517ms/step - loss: 0.1390 - accuracy: 0.9688 - val_loss: 0.1890 - val_accuracy: 0.9563
# Epoch 00039: early stopping

# %%
#save weights and model
if (hist):
    os.chdir(project_dir)
    os.chdir("./models")
    ss_config = "SS_" + str(ss_iterate_results) + "-" + str(iou_object_limit) + "-" + str(max_samples)
    tr_config = "_TR_E" + str(training_epochs) + "-SE" + str(steps_in_epoch) + "_VS-" + str(validation_steps) + "_" + model_architecture + "_OPT-" + str(optimizer)[27:31] + "_ES-" + str(early_stop) + "_AUG-" + str(do_augmentation)
    model_name = ss_config + tr_config + "_" + dataset_name
    model_final.save_weights(model_name + "_weights.h5")
    model_final.save(model_name + ".h5")

# %%
del hist
del traindata
del testdata

# %%
roboflow_evaluation = True;
if(roboflow_evaluation == True):
    roboflow_order = ["proc_05-05_NBC11595_KWtif-R003-C002_png.rf",
    "proc_05-05_NBC11595_KWtif-R009-C001_png.rf",
    "proc_05-05_NBC11595_KWtif-R009-C002_png.rf",
    "proc_05-05_NBC11595_KWtif-R011-C002_png.rf",
    "proc_05-05_NBC11595_KWtif-R011-C005_png.rf",
    "proc_15-03_YBC09857_KWtif-R001-C010_png.rf",
    "proc_15-03_YBC09857_KWtif-R002-C007_png.rf",
    "proc_15-03_YBC09857_KWtif-R003-C003_png.rf",
    "proc_15-03_YBC09857_KWtif-R003-C008_png.rf",
    "proc_15-03_YBC09857_KWtif-R004-C002_png.rf",
    "proc_15-03_YBC09857_KWtif-R004-C007_png.rf",
    "proc_15-03_YBC09857_KWtif-R004-C011_png.rf",
    "proc_15-03_YBC09857_KWtif-R005-C011_png.rf",
    "proc_15-03_YBC09857_KWtif-R006-C004_png.rf",
    "proc_15-03_YBC09857_KWtif-R006-C005_png.rf",
    "proc_MLC02627_o_KWtif-R001-C002_png.rf",
    "proc_MLC02627_o_KWtif-R005-C004_png.rf",
    "proc_MLC02627_o_KWtif-R005-C008_png.rf",
    "proc_MLC02627_o_KWtif-R007-C008_png.rf",
    "proc_MLC02627_r_KWtif-R002-C007_png.rf",
    "proc_YBC02145_obverse_KWtif-R004-C006_png.rf",
    "proc_YBC02145_obverse_KWtif-R006-C006_png.rf",
    "proc_YBC02145_obverse_KWtif-R008-C002_png.rf",
    "proc_YBC02145_obverse_KWtif-R008-C005_png.rf",
    "proc_YBC02152tif-R005-C008_png.rf",
    "proc_YBC02152tif-R009-C010_png.rf",
    "proc_YBC02152tif-R010-C010_png.rf",
    "proc_YBC02152tif-R015-C005_png.rf",
    "proc_YBC02152tif-R015-C009_png.rf",
    "proc_YBC02246_o_KWtif-R003-C003_png.rf",
    "proc_YBC02246_o_KWtif-R006-C010_png.rf",
    "proc_YBC02246_o_KWtif-R009-C005_png.rf",
    "proc_YBC02246_o_KWtif-R010-C006_png.rf",
    "proc_YBC02246_o_KWtif-R010-C007_png.rf",
    "proc_YBC02246_o_KWtif-R011-C010_png.rf",
    "proc_YBC02246_o_KWtif-R015-C003_png.rf",
    "proc_YBC02246_o_KWtif-R015-C007_png.rf",
    "proc_YBC02246_o_KWtif-R015-C010_png.rf",
    "proc_YBC02246_r_KWtif-R006-C005_png.rf",
    "proc_YBC02246_r_KWtif-R007-C006_png.rf",
    "proc_YBC02246_r_KWtif-R008-C009_png.rf",
    "proc_YBC02246_r_KWtif-R009-C009_png.rf",
    "proc_YBC02246_r_KWtif-R009-C010_png.rf",
    "proc_YBC02246_r_KWtif-R014-C004_png.rf",
    "proc_YBC04621_KWtif-R002-C011_png.rf",
    "proc_YBC04621_KWtif-R004-C011_png.rf",
    "proc_YBC04621_KWtif-R004-C012_png.rf",
    "proc_YBC04621_KWtif-R005-C012_png.rf",
    "proc_YBC04621_KWtif-R006-C007_png.rf",
    "proc_YBC04621_KWtif-R006-C011_png.rf",
    "proc_YBC04621_KWtif-R006-C015_png.rf",
    "proc_YBC04621_KWtif-R007-C006_png.rf",
    "proc_YBC04621_KWtif-R007-C014_png.rf",
    "proc_YBC04621_KWtif-R007-C015_png.rf",
    "proc_YBC04621_KWtif-R011-C012_png.rf",
    "proc_YBC05074tif-R004-C010_png.rf",
    "proc_YBC05074tif-R005-C008_png.rf",
    "proc_YBC07140tif-R004-C007_png.rf",
    "proc_YBC07140tif-R013-C008_png.rf",
    "proc_YBC07140tif-R015-C009_png.rf",
    "proc_YBC07169tif-R001-C009_png.rf",
    "proc_YBC07169tif-R002-C008_png.rf",
    "proc_YBC07169tif-R002-C010_png.rf",
    "proc_YBC07169tif-R003-C006_png.rf",
    "proc_YBC07169tif-R004-C010_png.rf",
    "proc_YBC07169tif-R006-C009_png.rf",
    "proc_YBC07169tif-R007-C005_png.rf",
    "proc_YBC07169tif-R007-C007_png.rf",
    "proc_YBC07169tif-R010-C007_png.rf",
    "proc_YBC07169tif-R012-C010_png.rf",
    "proc_YBC07169tif-R013-C006_png.rf",
    "proc_YBC07169tif-R013-C008_png.rf",
    "proc_YBC07169tif-R013-C010_png.rf",
    "proc_YBC07169tif-R014-C005_png.rf",
    "proc_YBC07169tif-R014-C006_png.rf",
    "proc_YBC07169tif-R014-C011_png.rf",
    "proc_YBC07169tif-R018-C013_png.rf",
    "proc_YBC07169tif-R018-C014_png.rf",
    "proc_YBC07169tif-R019-C009_png.rf",
    "proc_YBC07169tif-R021-C006_png.rf",
    "proc_YBC07169tif-R024-C006_png.rf",
    "proc_YBC07169tif-R027-C005_png.rf"]
    for j in range(100):
        roboflow_order.append("OUT_OF_RANGE_" + str(j))

# %%
validation_set_name = "224_one"
test_labels = os.path.join(test_data_dir, validation_set_name)
test_labels = test_labels.replace("\\","/")
matched = 0
os.chdir(test_labels)
labels_in_images=[]

for i in roboflow_order:
    result = []
    for filename in os.listdir(test_labels):
        if filename.endswith("xml"):
            x = re.search(str(i), str(filename))
            if(x):
                matched = matched + 1
                file  = open(filename, 'r').read()
                count = file.count("</object>")
                labels_in_images.append(count)

for j in range(100):
    labels_in_images.append(999+j)

# %%
class Region:
  def __init__ (self, x, y, w, h):
        self.x      = x
        self.y      = y
        self.w      = w
        self.h      = h

def removeIfDuplicate(x,y,w,h,found_regions, threshold, confidence, allowed_occupation_rate):
    print("I have found a potential object -  confidence, threshold: ", confidence, threshold)
    score_list = []
    for region in found_regions:
        score_h = 0
        score_v = 0
        score_h_right = 0
        score_h_left = 0
        score_v_top = 0
        score_v_bottom = 0
        print("I have this regions to compare with: ", len(found_regions))
        if((x >= region.x) and (x+w <= region.x+region.w) and (y >= region.y) and (y+h <= region.y+region.h)):
            print("object is already part of a greater object")
            return False
        else:
            if((x >= region.x) and (x <= (region.x+region.w))):
                distance_right  = (region.x + region.w) - x
                incoming_object_horizontal_occupation = distance_right / w
                existing_object_horizontal_occupation = distance_right / region.w
                print("horizontal occupataions between each others are: ", existing_object_horizontal_occupation, incoming_object_horizontal_occupation)
                if incoming_object_horizontal_occupation >= existing_object_horizontal_occupation:
                    score_h_right = incoming_object_horizontal_occupation
                else:
                    score_h_right = existing_object_horizontal_occupation
            if(((x+w) >= region.x) and ((x+w)<=(region.x+region.w))):
                distance_left   = x+w - region.x
                incoming_object_horizontal_occupation = distance_left / w
                existing_object_horizontal_occupation = distance_left / region.w
                print("horizontal occupations between each others are: ", incoming_object_horizontal_occupation, existing_object_horizontal_occupation)
                if incoming_object_horizontal_occupation >= existing_object_horizontal_occupation:
                    score_h_left = incoming_object_horizontal_occupation
                else:
                    score_h_left = existing_object_horizontal_occupation
            if((y >= region.y) and ((y) <= (region.y+region.h))):
                distance_up = (region.y + region.h) - y
                incoming_object_vertical_occupation = distance_up / h
                existing_object_vertical_occupation = distance_up / region.h
                print("vertical occupations between each others are:  ", incoming_object_vertical_occupation, existing_object_vertical_occupation)
                if(incoming_object_vertical_occupation >= existing_object_vertical_occupation):
                    score_v_top = incoming_object_vertical_occupation
                else:
                    score_v_top = existing_object_vertical_occupation
            if(((y+h) >= region.y) and ((y+h)<=(region.y+region.h))):
                distance_down = (y+h) - region.y
                incoming_object_vertical_occupation = distance_down / h
                existing_object_vertical_occupation = distance_down / region.h
                print("vertical occupations between each others are:  ", incoming_object_vertical_occupation, existing_object_vertical_occupation)
                if(incoming_object_vertical_occupation >= existing_object_vertical_occupation):
                    score_v_bottom = incoming_object_vertical_occupation
                else:
                    score_v_bottom = existing_object_vertical_occupation
            if(((score_h_left > allowed_occupation_rate) or (score_h_right > allowed_occupation_rate)) and ((score_v_top > allowed_occupation_rate) or (score_v_bottom > allowed_occupation_rate))):
                print("I found it duplicate, returning False")
                return False
            #if((score_h  <=  0.5) or (score_v <= 0.5)):
            #    print("I found it great, returning True")
            #    return True
    return True

# %%
def plotRectangles(out, threshold, x, y, w, h, found_regions, allowed_occupation_rate):
    if out[0][0] > threshold:
                    originality = removeIfDuplicate(x,y,w,h, found_regions, threshold, out[0][0], allowed_occupation_rate)
                    if(originality == True):
                        print("we shall plot rectangle")
                        return True
                    if(originality == False):
                        print("we shall not plot rectangle")
                        return False

# %%
os.chdir(models_dir)
prediction_model = keras.models.load_model('SS_2000-0.7-55_TR_E100-SE100_VS-5_vgg_imagenet_OPT-adam_ES-True_AUG-False_224_full.h5')    # model_finale 
os.chdir(test_data_dir)
test_images = os.path.join(test_data_dir, validation_set_name)
threshold = 0.07
threshold_step_rate = 2
threshold_number_of_steps = 2
roboflow_index=0
allowed_occupation_rate = 0.5
z=0
discovered_duplicates = 0
for e,i in enumerate(os.listdir(test_images)):
    if i.endswith("jpg"):
        print("Found file: ", i)
        z += 1
        img = cv2.imread(os.path.join(test_images,i))
        ss.setBaseImage(img)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process() 
        imout = img.copy()
        region_index=0
        found_regions = [];
        helper = 0
        for step in range(threshold_number_of_steps):
            if(helper == threshold):
                print("NO NEED TO REPEAT EVALUATION PROCESS")
            else:
                helper = threshold
                for e,result in enumerate(ssresults):
                    if e < 2000:
                        x,y,w,h = result
                        timage = imout[y:y+h,x:x+w]
                        resized = cv2.resize(timage, (image_edge_lenght,image_edge_lenght), interpolation = cv2.INTER_AREA)
                        img = np.expand_dims(resized, axis=0)
                        out= prediction_model.predict(img)
                        plotRectangle = plotRectangles(out, threshold, x, y, w, h, found_regions, allowed_occupation_rate)
                        if(plotRectangle == True):
                            print("I am plotting it")
                            cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
                            region_index += 1
                            region = Region(x,y,w,h)
                            found_regions.append(region)
                        if(plotRectangle == False):
                            print("I am not plotting it")
                            discovered_duplicates +=  1
            if(len(found_regions)==0):
                threshold = threshold / threshold_step_rate 
        plt.figure()
        plt.imshow(imout)
        os.chdir(results_dir)
        cv2.imwrite(i, imout)
        new_name = str(roboflow_index) + "_" + str(region_index) + "_" + str(labels_in_images[roboflow_index]) + "_" + str(roboflow_order[roboflow_index]) + ".jpg"
        os.rename(i, new_name)
        os.chdir(test_data_dir)
        roboflow_index += 1
print("OPERATION FINISHED, PREVENTED DUCPLICATES: ", discovered_duplicates)
# Out:
# Found file:  proc_05-05_NBC11595_KWtif-R002-C003_png.rf.ff0ba015844b37b4c6f44f0c8ed5f938.jpg
# I have found a potential object -  confidence, threshold:  0.08217009 0.07
# we shall plot rectangle
# I am plotting it
# I have found a potential object -  confidence, threshold:  0.13045953 0.07
# I have this regions to compare with:  1
# we shall plot rectangle
# I am plotting it
# I have found a potential object -  confidence, threshold:  0.10775563 0.07
# I have this regions to compare with:  2
# vertical occupations between each others are:   0.48 0.7058823529411765
# I have this regions to compare with:  2
# we shall plot rectangle
# I am plotting it
# I have found a potential object -  confidence, threshold:  0.1798722 0.07
# I have this regions to compare with:  3
# I have this regions to compare with:  3
# horizontal occupations between each others are:  0.8048780487804879 0.7021276595744681
# I have this regions to compare with:  3
# we shall plot rectangle
# I am plotting it
# I have found a potential object -  confidence, threshold:  0.11995937 0.07
# I have this regions to compare with:  4
# I have this regions to compare with:  4
# I have this regions to compare with:  4
# horizontal occupations between each others are:  0.1643835616438356 0.3157894736842105
# I have this regions to compare with:  4
# horizontal occupataions between each others are:  1.0 0.5616438356164384
# vertical occupations between each others are:   0.9655172413793104 1.0
# I found it duplicate, returning False
# we shall not plot rectangle
# I am not plotting it
# I have found a potential object -  confidence, threshold:  0.23184538 0.07
# I have this regions to compare with:  4
# I have this regions to compare with:  4
# horizontal occupations between each others are:  0.8048780487804879 0.7021276595744681
# I have this regions to compare with:  4
# I have this regions to compare with:  4
# object is already part of a greater object
# we shall not plot rectangle
# I am not plotting it
# I have found a potential object -  confidence, threshold:  0.09938635 0.07
# I have this regions to compare with:  4
# I have this regions to compare with:  4
# horizontal occupataions between each others are:  0.723404255319149 0.8717948717948718
# I have this regions to compare with:  4
# I have this regions to compare with:  4
# horizontal occupataions between each others are:  0.4878048780487805 0.5128205128205128
# we shall plot rectangle
# I am plotting it
# I have found a potential object -  confidence, threshold:  0.11536466 0.07
# I have this regions to compare with:  5
# vertical occupations between each others are:   0.1875 0.17647058823529413
# I have this regions to compare with:  5
# I have this regions to compare with:  5
# horizontal occupataions between each others are:  0.7105263157894737 0.6
# vertical occupations between each others are:   1.0 0.64
# vertical occupations between each others are:   1.5625 1.0
# I found it duplicate, returning False
# we shall not plot rectangle
# I am not plotting it
# I have found a potential object -  confidence, threshold:  0.089544125 0.07
# I have this regions to compare with:  5
# I have this regions to compare with:  5
# I have this regions to compare with:  5
# horizontal occupations between each others are:  0.34408602150537637 0.8421052631578947
# I have this regions to compare with:  5
# horizontal occupataions between each others are:  1.0 0.44086021505376344
# vertical occupations between each others are:   0.6511627906976745 1.0
# I found it duplicate, returning False
# we shall not plot rectangle
# I am not plotting it
# I have found a potential object -  confidence, threshold:  0.20746124 0.07
# I have this regions to compare with:  5
# vertical occupations between each others are:   0.38095238095238093 0.47058823529411764
# I have this regions to compare with:  5
# I have this regions to compare with:  5
# vertical occupations between each others are:   1.0 0.84
# vertical occupations between each others are:   1.1904761904761905 1.0
# I have this regions to compare with:  5
# I have this regions to compare with:  5
# horizontal occupataions between each others are:  0.02564102564102564 0.017241379310344827
# we shall plot rectangle
# I am plotting it
# I have found a potential object -  confidence, threshold:  0.17051812 0.07
# I have this regions to compare with:  6
# I have this regions to compare with:  6
# horizontal occupations between each others are:  0.9787234042553191 0.9787234042553191
# vertical occupations between each others are:   1.0 0.9444444444444444
# vertical occupations between each others are:   1.0588235294117647 1.0
# I found it duplicate, returning False
# we shall not plot rectangle
# I am not plotting it
# I have found a potential object -  confidence, threshold:  0.22767013 0.07
# I have this regions to compare with:  6
# vertical occupations between each others are:   0.48 0.7058823529411765
# I have this regions to compare with:  6
# I have this regions to compare with:  6
# vertical occupations between each others are:   1.0 1.0
# vertical occupations between each others are:   1.0 1.0
# I have this regions to compare with:  6
# I have this regions to compare with:  6
# horizontal occupataions between each others are:  0.02564102564102564 0.017241379310344827
# I have this regions to compare with:  6
# horizontal occupataions between each others are:  1.0 1.0
# horizontal occupations between each others are:  1.0 1.0
# vertical occupations between each others are:   0.84 1.0
# I found it duplicate, returning False
# we shall not plot rectangle
# I am not plotting it
# I have found a potential object -  confidence, threshold:  0.15879436 0.07
# I have this regions to compare with:  6
# I have this regions to compare with:  6
# horizontal occupations between each others are:  0.9787234042553191 0.9787234042553191
# vertical occupations between each others are:   1.0 1.0
# vertical occupations between each others are:   1.0 1.0
# I found it duplicate, returning False
# we shall not plot rectangle
# I am not plotting it
# I have found a potential object -  confidence, threshold:  0.105711035 0.07
# I have this regions to compare with:  6
# I have this regions to compare with:  6
# I have this regions to compare with:  6
# horizontal occupations between each others are:  0.1643835616438356 0.3157894736842105
# I have this regions to compare with:  6
# horizontal occupataions between each others are:  1.0 0.5616438356164384
# vertical occupations between each others are:   1.0 1.0
# vertical occupations between each others are:   1.0 1.0
# I found it duplicate, returning False
# we shall not plot rectangle
# I am not plotting it
# I have found a potential object -  confidence, threshold:  0.119906045 0.07
# I have this regions to compare with:  6
# I have this regions to compare with:  6
# I have this regions to compare with:  6
# horizontal occupations between each others are:  0.1643835616438356 0.3157894736842105
# I have this regions to compare with:  6
# horizontal occupataions between each others are:  1.0 0.5616438356164384
# vertical occupations between each others are:   1.0 0.8928571428571429
# vertical occupations between each others are:   1.12 1.0
# I found it duplicate, returning False
# we shall not plot rectangle
# I am not plotting it
# NO NEED TO REPEAT EVALUATION PROCESS
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1912\3821320930.py in <module>
#      51         cv2.imwrite(i, imout)
#      52         new_name = str(roboflow_index) + "_" + str(region_index) + "_" + str(labels_in_images[roboflow_index]) + "_" + str(roboflow_order[roboflow_index]) + ".jpg"
# ---> 53         os.rename(i, new_name)
#      54         os.chdir(test_data_dir)
#      55         roboflow_index += 1
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'proc_05-05_NBC11595_KWtif-R002-C003_png.rf.ff0ba015844b37b4c6f44f0c8ed5f938.jpg' -> '0_6_999_proc_05-05_NBC11595_KWtif-R003-C002_png.rf.jpg'

# %%
os.chdir(models_dir)
prediction_model = keras.models.load_model('SS_2000-0.7-55_TR_E100-SE100_VS-5_vgg_imagenet_OPT-adam_ES-True_AUG-False_224_full.h5')
os.chdir(test_data_dir)
test_images = "./224_one/"
z=0
for e,i in enumerate(os.listdir(test_images)):
    if i.endswith("jpg"):
        print("Found file: ", i)
        z += 1
        img = cv2.imread(os.path.join(test_images,i))
        ss.setBaseImage(img)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process() 
        imout = img.copy()
        for e,result in enumerate(ssresults):
            if e < 2000:
                x,y,w,h = result
                timage = imout[y:y+h,x:x+w]
                resized = cv2.resize(timage, (image_edge_lenght,image_edge_lenght), interpolation = cv2.INTER_AREA)
                img = np.expand_dims(resized, axis=0)
                out= prediction_model.predict(img)
                #out= model_final.local(img)
                #print(out[0][0])
                if out[0][0] > 0.07:
                    cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
        plt.figure()
        plt.imshow(imout)
        cv2.imwrite(i, imout)
# Out:
# Found file:  proc_05-05_NBC11595_KWtif-R002-C003_png.rf.ff0ba015844b37b4c6f44f0c8ed5f938.jpg

# %%
del model_final
del prediction_model
